# %%
# Importing Libraries
import serial
import time
arduino = serial.Serial(port='/dev/cu.usbmodem39174101', baudrate=115200, timeout=.1)

payload = []

def read(x):
    time.sleep(0.1)
    data = arduino.readline()
    return data
while True:
    value = read(arduino)
    payload.append(value.decode("utf-8")) # printing the value
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/pyserial/lib/python3.9/site-packages/serial/serialposix.py in open(self)
#     321         try:
# --> 322             self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     323         except OSError as msg:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/dev/cu.usbmodem39174101'
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# <ipython-input-1-7d66e9d18a7f> in <module>
#       2 import serial
#       3 import time
# ----> 4 arduino = serial.Serial(port='/dev/cu.usbmodem39174101', baudrate=115200, timeout=.1)
#       5
#       6 payload = []
#
# ~/anaconda3/envs/pyserial/lib/python3.9/site-packages/serial/serialutil.py in __init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     242
#     243         if port is not None:
# --> 244             self.open()
#     245
#     246     #  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#
# ~/anaconda3/envs/pyserial/lib/python3.9/site-packages/serial/serialposix.py in open(self)
#     323         except OSError as msg:
#     324             self.fd = None
# --> 325             raise SerialException(msg.errno, "could not open port {}: {}".format(self._port, msg))
#     326         #~ fcntl.fcntl(self.fd, fcntl.F_SETFL, 0)  # set blocking
#     327
#
# SerialException: [Errno 2] could not open port /dev/cu.usbmodem39174101: [Errno 2] No such file or directory: '/dev/cu.usbmodem39174101'

# %%
payload = [
 '20  |Z|=6324.56\r\n',
 '30  |Z|=8744.75\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=10000.00\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=11401.75\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=13254.27\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=8744.75\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=12747.55\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=11401.75\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=12747.55\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=11401.75\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=9776.92\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=12747.55\r\n',
 '40  |Z|=9235.48\r\n',
 '50  |Z|=9776.92\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=12747.55\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=11401.75\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=16124.52\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=13826.66\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=12747.55\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=13826.66\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=9776.92\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=9776.92\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=11401.75\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=12747.55\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=8744.75\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=10000.00\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=7071.07\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=13254.27\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=8744.75\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=11401.75\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=7071.07\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=12747.55\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=12747.55\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=10000.00\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=11401.75\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=10000.00\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=11401.75\r\n',
 '40  |Z|=12041.59\r\n',
 '50  |Z|=9776.92\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=11401.75\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=12747.55\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=8744.75\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=11074.36\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=11401.75\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=10000.00\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=8027.73\r\n',
 '50  |Z|=12747.55\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=10000.00\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=12747.55\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=8744.75\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=12747.55\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=11401.75\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=11401.75\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=10000.00\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=12018.50\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=12747.55\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=12747.55\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=8514.69\r\n',
 '50  |Z|=9776.92\r\n',
 '   \r\n',
 '20  |Z|=6324.56\r\n',
 '30  |Z|=10000.00\r\n',
 '40  |Z|=10000.00\r\n',
 '50  |Z|=9776.92\r\n',
 '   \r\n',
 '20  |Z|=10000.00\r\n']

# %%
# Out:
# [6324.56,
#  8744.75,
#  10000.0,
#  10000.0,
#  10000.0,
#  11401.75,
#  8514.69,
#  13254.27,
#  10000.0,
#  8744.75,
#  10000.0,
#  12747.55,
#  6324.56,
#  11401.75,
#  8514.69,
#  12747.55,
#  10000.0,
#  11401.75,
#  8514.69,
#  9776.92,
#  6324.56,
#  12747.55,
#  9235.48,
#  9776.92,
#  10000.0,
#  10000.0,
#  10000.0,
#  12747.55,
#  6324.56,
#  10000.0,
#  10000.0,
#  11401.75,
#  10000.0,
#  16124.52,
#  10000.0,
#  13826.66,
#  10000.0,
#  10000.0,
#  8514.69,
#  12747.55,
#  6324.56,
#  10000.0,
#  8514.69,
#  13826.66,
#  10000.0,
#  10000.0,
#  8514.69,
#  9776.92,
#  6324.56,
#  10000.0,
#  10000.0,
#  9776.92,
#  6324.56,
#  11401.75,
#  10000.0,
#  12747.55,
#  6324.56,
#  8744.75,
#  10000.0,
#  10000.0,
#  6324.56,
#  7071.07,
#  8514.69,
#  13254.27,
#  6324.56,
#  8744.75,
#  10000.0,
#  11401.75,
#  6324.56,
#  7071.07,
#  10000.0,
#  12747.55,
#  10000.0,
#  10000.0,
#  10000.0,
#  12747.55,
#  10000.0,
#  10000.0,
#  10000.0,
#  10000.0,
#  6324.56,
#  11401.75,
#  8514.69,
#  10000.0,
#  6324.56,
#  11401.75,
#  12041.59,
#  9776.92,
#  6324.56,
#  11401.75,
#  8514.69,
#  12747.55,
#  10000.0,
#  8744.75,
#  10000.0,
#  11074.36,
#  6324.56,
#  11401.75,
#  10000.0,
#  10000.0,
#  10000.0,
#  10000.0,
#  8027.73,
#  12747.55,
#  10000.0,
#  10000.0,
#  8514.69,
#  10000.0,
#  6324.56,
#  10000.0,
#  8514.69,
#  12747.55,
#  6324.56,
#  8744.75,
#  8514.69,
#  12747.55,
#  6324.56,
#  11401.75,
#  10000.0,
#  11401.75,
#  6324.56,
#  10000.0,
#  10000.0,
#  10000.0,
#  6324.56,
#  12018.5,
#  8514.69,
#  12747.55,
#  10000.0,
#  10000.0,
#  8514.69,
#  12747.55,
#  10000.0,
#  10000.0,
#  8514.69,
#  9776.92,
#  6324.56,
#  10000.0,
#  10000.0,
#  9776.92,
#  10000.0]

# %%
import random
from itertools import count
import time
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.patches import Circle, PathPatch
from matplotlib.text import TextPath
from matplotlib.transforms import Affine2D

# plt.style.use('fivethirtyeight')

def fakeread(step):
    return 

x_values = []
y_values = []
index = count()
def animate(i):
    
#     data = [i.split("  ") for i in payload]
#     group = [i[0] for i in data if i[0] != '']
#     value = [i[1].rstrip('\r\n') for i in data]
#     value = [float(i.split('=')[1]) for i in value if i != ' ']

    x = next(index)
    x_values.append(x)
    y = random.randint(0, 5)
    y_values.append(y)

    ax.plot(x_values, y_values, 'blue',linestyle='--')

    time.sleep(.5)

fig = plt.figure()
ax = plt.axes()    
ani = FuncAnimation(plt.gcf(), animate, 10)


plt.tight_layout()
plt.show()

# %%
import pandas as pd

df = pd.DataFrame(payload)
df.columns = ['value']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a1a5679963ec> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.DataFrame(payload)
#       4 df.columns = ['value']
#
# NameError: name 'payload' is not defined

# %%
df['group'] = df['value'].str.split("  ", expand=True)[0]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-aa3d9907418c> in <module>
# ----> 1 df['group'] = df['value'].str.split("  ", expand=True)[0]
#       2 df
#
# NameError: name 'df' is not defined

# %%
df['impedence'] = pd.to_numeric(df['value'].str.split("  ", expand=True)[1].str.rstrip('\r\n').str.split('=', expand = True)[1])
filtered_data = df[['group','impedence']].dropna()

# %%
filtered_data
# Out:
#     group  impedence
# 1      50   13826.66
# 3      20    6324.56
# 4      30    8744.75
# 5      40   10000.00
# 6      50   10000.00
# ..    ...        ...
# 173    20    6324.56
# 174    30   10000.00
# 175    40   10000.00
# 176    50    9776.92
# 178    20   10000.00
#
# [142 rows x 2 columns]

# %%
import matplotlib
filtered_data.groupby('group').plot()
# Out:
# group
# 20    AxesSubplot(0.125,0.125;0.775x0.755)
# 30    AxesSubplot(0.125,0.125;0.775x0.755)
# 40    AxesSubplot(0.125,0.125;0.775x0.755)
# 50    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
